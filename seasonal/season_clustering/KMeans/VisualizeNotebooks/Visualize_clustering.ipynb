# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from _config import *

cluster_file = r'C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2022.csv'
station_mapping = pd.read_csv(os.getenv('STATION_MAPPING'), dtype=str)
shape_file = Path(os.getenv('SHAPE_FILE'))
# Out:
# -------------------------------------------------
# ----- Environment variables from .env file: -----
# -------------------------------------------------
# -------------------------------------------------

# %% [markdown]
# # Loading catchment data shape file .shp

# %%
all_catchments_gdf = gpd.read_file(shape_file)
print(all_catchments_gdf.shape)
print(all_catchments_gdf.columns)
all_catchments_gdf.head()
# Out:
# (3447, 4)
# Index(['Id15_v30', 'area', 'hypeid', 'geometry'], dtype='object')
#    Id15_v30          area  hypeid  \
# 0  11100001  3.222040e+07       1
# 1  11100003  3.057747e+07       2
# 2  11100004  1.825017e+07       3
# 3  11100005  1.534746e+07       4
# 4  11100006  1.524262e+07       5
#
#                                             geometry
# 0  POLYGON Z ((477487.121 6325222.212 0, 477543.1...
# 1  POLYGON Z ((474003.147 6316165.657 0, 473870.1...
# 2  MULTIPOLYGON Z (((468046.994 6317094.258 0, 46...
# 3  POLYGON Z ((466052.174 6318307.21 0, 466150.17...
# 4  POLYGON Z ((476077.142 6328208.222 0, 476062.1...

# %% [markdown]
# # Loading clustering file
# Assumes file with format:
# ```csv
# CID,Cluster
# 10000009,0
# 10000010,1
# ...
# ```

# %%
cluster_mapping = pd.read_csv(cluster_file, dtype=str)
cluster_mapping.columns = ['id', 'cluster']
cluster_mapping.head()
# Out:
#          id cluster
# 0  10000009       0
# 1  10000010       1
# 2  10000011       1
# 3  10000014       0
# 4  10000016       1

# %% [markdown]
# ## Map to Id15_v30

# %%
new_column = []
for catchment in cluster_mapping['id'].values:
    new_column.append(np.int64(station_mapping[station_mapping["obsstednr"] == catchment]["Id15_v30"].values[0]))

cluster_mapping['Id15_v30'] = new_column
cluster_mapping.drop(columns=['id'], inplace=True)
display(cluster_mapping.head())
# Out:
#   cluster  Id15_v30
# 0       0  37240441
# 1       1  37210639
# 2       1  37150512
# 3       0  37230017
# 4       1  37220017

# %% [markdown]
# ## Filter to available catchments

# %%
import numpy as np

# filter out gauged catchments
idxs = all_catchments_gdf['Id15_v30'].isin([np.int64(x) for x in cluster_mapping['Id15_v30'].values])
gauged_catchments_gdf = all_catchments_gdf[idxs]
ungauged_catchments_gdf = all_catchments_gdf[idxs == False]
print(gauged_catchments_gdf.shape)
print(ungauged_catchments_gdf.shape)
# Out:
# (347, 4)
# (3100, 4)

# %% [markdown]
# ## Merge shape file and dataframe

# %%
merged_gdf = gauged_catchments_gdf.merge(cluster_mapping, on='Id15_v30')
merged_gdf['area'] = merged_gdf.geometry.area
print(merged_gdf.shape)
merged_gdf.head()
# Out:
# (347, 5)
#    Id15_v30          area  hypeid  \
# 0  12410010  4.095361e+07      31
# 1  12410023  1.727513e+07      35
# 2  12411515  1.254289e+08      45
# 3  12420023  8.062677e+07      52
# 4  12430399  9.708061e+08      70
#
#                                             geometry cluster
# 0  POLYGON Z ((455692.442 6256547.471 0, 455602.4...       1
# 1  POLYGON Z ((450578.458 6258299.415 0, 450563.4...       1
# 2  POLYGON Z ((461092.449 6250737.547 0, 461057.4...       1
# 3  POLYGON Z ((461359.473 6246241.584 0, 461351.4...       0
# 4  POLYGON Z ((480362.318 6231433.26 0, 480369.39...       0

# %% [markdown]
# # Plot by cluster (assumes `cluster` column)

# %%
cmap = "tab20"
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(8, 5))

# Plot without automatic legend
merged_gdf.sort_values(by="area", ascending=False).plot(
    column="cluster",
    figsize=(25, 15),
    ax=ax,
    legend=False,  # turn off auto legend
    cmap=cmap
)

ax.set_title(f"Spring 2022 Clustering")

# Add Denmark boundary
denmark_boundary = all_catchments_gdf.boundary
denmark_boundary.plot(ax=ax, color='black', linewidth=0.02)

# Axis settings
ax.set_xlim(left=440000, right=730000)
ax.set_ylim(top=6.4e6, bottom=6.05e6)
ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)

# --------------------------------------------------------
#  CUSTOM LEGEND (3 columns, small size, upper-right)
# --------------------------------------------------------
import matplotlib as mpl
import matplotlib.patches as mpatches

# Treat cluster as categorical so we have a stable order
cluster_cat = merged_gdf["cluster"].astype("category")
clusters_ordered = list(cluster_cat.cat.categories)  # ordered categories

# New style colormap access (no deprecation warning)
cmap_obj = mpl.colormaps[cmap]  # or mpl.colormaps.get_cmap(cmap)

n_clusters = len(clusters_ordered)

handles = []
for i, c in enumerate(clusters_ordered):
    # Map category index to [0, 1] range for the colormap
    if n_clusters == 1:
        t = 0.5
    else:
        t = i / (n_clusters - 1)
    color = cmap_obj(t)

    handles.append(
        mpatches.Patch(
            color=color,
            label=str(c)
        )
    )

ax.legend(
    handles=handles,
    title="Clusters",
    loc="upper right",
    bbox_to_anchor=(1, 1),
    ncol=2,  # ⭐ three columns
    fontsize=6,  # small text
    title_fontsize=7,
    frameon=True,
    borderpad=0.3,
    handlelength=1.0
)

plt.tight_layout()
plt.savefig(
    str(Path(cluster_file).parent / Path(cluster_file).stem) + '.png',
    dpi=300, bbox_inches='tight'
)
plt.show()

# %% [markdown]
# ---
# # Plot the catchment area plot for data section.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

fig, ax = plt.subplots(1, 2, figsize=(8, 5))

# Define common normalization and colormap
vmin = merged_gdf["area"].min()
vmax = merged_gdf["area"].max()
cmap = "turbo"

# Plot the maps using a continuous color scale
merged_gdf.sort_values(by="area", ascending=False).plot(
    column="area", ax=ax[0], cmap=cmap, vmin=vmin, vmax=vmax, legend=False
)
merged_gdf.sort_values(by="area", ascending=True).plot(
    column="area", ax=ax[1], cmap=cmap, vmin=vmin, vmax=vmax, legend=False
)

# Titles
ax[0].set_title("Smallest catchments on top")
ax[1].set_title("Largest catchments on top")

# Remove y-axis from second plot
ax[1].set_yticks([])
ax[1].set_ylabel('')
ax[1].tick_params(left=False)

# Add Denmark boundary outlines
denmark_boundary = all_catchments_gdf.boundary
denmark_boundary.plot(ax=ax[0], color='black', linewidth=0.05)
denmark_boundary.plot(ax=ax[1], color='black', linewidth=0.05)

# Axis settings
ax[0].set_xlim(left=440000, right=730000)
ax[0].set_ylim(top=6.4e6, bottom=6.05e6)
ax[0].tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
ax[1].set_xlim(left=440000, right=730000)
ax[1].set_ylim(top=6.4e6, bottom=6.05e6)
ax[1].tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)

# Add a shared colorbar on the right
# Add a shared colorbar at the top center
sm = mpl.cm.ScalarMappable(norm=mpl.colors.Normalize(vmin=vmin, vmax=vmax), cmap=cmap)
sm._A = []

# Create a new axis for the colorbar spanning both subplots
cbar_ax = fig.add_axes([0.28, 0.927, 0.4, 0.03])  # [left, bottom, width, height]
cbar = fig.colorbar(sm, cax=cbar_ax, orientation='horizontal')
cbar.set_label("Catchment area", labelpad=2)


plt.tight_layout()
plt.savefig('gauged_catchments_area.png', dpi=300)
plt.show()
# Out:
# C:\Users\kscar\AppData\Local\Temp\ipykernel_39120\3937956479.py:52: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # Summer

# %%
cluster_file = r'C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2022.csv'
station_mapping = pd.read_csv(os.getenv('STATION_MAPPING'), dtype=str)
shape_file = Path(os.getenv('SHAPE_FILE'))

# %%
all_catchments_gdf = gpd.read_file(shape_file)
print(all_catchments_gdf.shape)
print(all_catchments_gdf.columns)
all_catchments_gdf.head()
# Out:
# (3447, 4)
# Index(['Id15_v30', 'area', 'hypeid', 'geometry'], dtype='object')
#    Id15_v30          area  hypeid  \
# 0  11100001  3.222040e+07       1
# 1  11100003  3.057747e+07       2
# 2  11100004  1.825017e+07       3
# 3  11100005  1.534746e+07       4
# 4  11100006  1.524262e+07       5
#
#                                             geometry
# 0  POLYGON Z ((477487.121 6325222.212 0, 477543.1...
# 1  POLYGON Z ((474003.147 6316165.657 0, 473870.1...
# 2  MULTIPOLYGON Z (((468046.994 6317094.258 0, 46...
# 3  POLYGON Z ((466052.174 6318307.21 0, 466150.17...
# 4  POLYGON Z ((476077.142 6328208.222 0, 476062.1...

# %%
cluster_mapping = pd.read_csv(cluster_file, dtype=str)
cluster_mapping.columns = ['id', 'cluster']
cluster_mapping.head()
# Out:
#          id cluster
# 0  10000009       0
# 1  10000010       1
# 2  10000011       1
# 3  10000014       0
# 4  10000016       1

# %%
new_column = []
for catchment in cluster_mapping['id'].values:
    new_column.append(np.int64(station_mapping[station_mapping["obsstednr"] == catchment]["Id15_v30"].values[0]))

cluster_mapping['Id15_v30'] = new_column
cluster_mapping.drop(columns=['id'], inplace=True)
display(cluster_mapping.head())
# Out:
#   cluster  Id15_v30
# 0       0  37240441
# 1       1  37210639
# 2       1  37150512
# 3       0  37230017
# 4       1  37220017

# %%
import numpy as np

# filter out gauged catchments
idxs = all_catchments_gdf['Id15_v30'].isin([np.int64(x) for x in cluster_mapping['Id15_v30'].values])
gauged_catchments_gdf = all_catchments_gdf[idxs]
ungauged_catchments_gdf = all_catchments_gdf[idxs == False]
print(gauged_catchments_gdf.shape)
print(ungauged_catchments_gdf.shape)
# Out:
# (347, 4)
# (3100, 4)

# %%
merged_gdf = gauged_catchments_gdf.merge(cluster_mapping, on='Id15_v30')
merged_gdf['area'] = merged_gdf.geometry.area
print(merged_gdf.shape)
merged_gdf.head()
# Out:
# (347, 5)
#    Id15_v30          area  hypeid  \
# 0  12410010  4.095361e+07      31
# 1  12410023  1.727513e+07      35
# 2  12411515  1.254289e+08      45
# 3  12420023  8.062677e+07      52
# 4  12430399  9.708061e+08      70
#
#                                             geometry cluster
# 0  POLYGON Z ((455692.442 6256547.471 0, 455602.4...       1
# 1  POLYGON Z ((450578.458 6258299.415 0, 450563.4...       1
# 2  POLYGON Z ((461092.449 6250737.547 0, 461057.4...       1
# 3  POLYGON Z ((461359.473 6246241.584 0, 461351.4...       0
# 4  POLYGON Z ((480362.318 6231433.26 0, 480369.39...       0

# %%
cmap = "tab20"
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(8, 5))

# Plot without automatic legend
merged_gdf.sort_values(by="area", ascending=False).plot(
    column="cluster",
    figsize=(25, 15),
    ax=ax,
    legend=False,  # turn off auto legend
    cmap=cmap
)

ax.set_title(f"Summer 2022 Clustering")

# Add Denmark boundary
denmark_boundary = all_catchments_gdf.boundary
denmark_boundary.plot(ax=ax, color='black', linewidth=0.02)

# Axis settings
ax.set_xlim(left=440000, right=730000)
ax.set_ylim(top=6.4e6, bottom=6.05e6)
ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)

# --------------------------------------------------------
#  CUSTOM LEGEND (3 columns, small size, upper-right)
# --------------------------------------------------------
import matplotlib as mpl
import matplotlib.patches as mpatches

# Treat cluster as categorical so we have a stable order
cluster_cat = merged_gdf["cluster"].astype("category")
clusters_ordered = list(cluster_cat.cat.categories)  # ordered categories

# New style colormap access (no deprecation warning)
cmap_obj = mpl.colormaps[cmap]  # or mpl.colormaps.get_cmap(cmap)

n_clusters = len(clusters_ordered)

handles = []
for i, c in enumerate(clusters_ordered):
    # Map category index to [0, 1] range for the colormap
    if n_clusters == 1:
        t = 0.5
    else:
        t = i / (n_clusters - 1)
    color = cmap_obj(t)

    handles.append(
        mpatches.Patch(
            color=color,
            label=str(c)
        )
    )

ax.legend(
    handles=handles,
    title="Clusters",
    loc="upper right",
    bbox_to_anchor=(1, 1),
    ncol=2,  # ⭐ three columns
    fontsize=6,  # small text
    title_fontsize=7,
    frameon=True,
    borderpad=0.3,
    handlelength=1.0
)

plt.tight_layout()
plt.savefig(
    str(Path(cluster_file).parent / Path(cluster_file).stem) + '.png',
    dpi=300, bbox_inches='tight'
)
plt.show()

# %% [markdown]
# # Fall

# %%
cluster_file = r'C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2022.csv'
station_mapping = pd.read_csv(os.getenv('STATION_MAPPING'), dtype=str)
shape_file = Path(os.getenv('SHAPE_FILE'))

# %%
all_catchments_gdf = gpd.read_file(shape_file)
print(all_catchments_gdf.shape)
print(all_catchments_gdf.columns)
all_catchments_gdf.head()
# Out:
# (3447, 4)
# Index(['Id15_v30', 'area', 'hypeid', 'geometry'], dtype='object')
#    Id15_v30          area  hypeid  \
# 0  11100001  3.222040e+07       1
# 1  11100003  3.057747e+07       2
# 2  11100004  1.825017e+07       3
# 3  11100005  1.534746e+07       4
# 4  11100006  1.524262e+07       5
#
#                                             geometry
# 0  POLYGON Z ((477487.121 6325222.212 0, 477543.1...
# 1  POLYGON Z ((474003.147 6316165.657 0, 473870.1...
# 2  MULTIPOLYGON Z (((468046.994 6317094.258 0, 46...
# 3  POLYGON Z ((466052.174 6318307.21 0, 466150.17...
# 4  POLYGON Z ((476077.142 6328208.222 0, 476062.1...

# %%
cluster_mapping = pd.read_csv(cluster_file, dtype=str)
cluster_mapping.columns = ['id', 'cluster']
cluster_mapping.head()
# Out:
#          id cluster
# 0  10000009       1
# 1  10000010       1
# 2  10000011       0
# 3  10000014       1
# 4  10000016       0

# %%
new_column = []
for catchment in cluster_mapping['id'].values:
    new_column.append(np.int64(station_mapping[station_mapping["obsstednr"] == catchment]["Id15_v30"].values[0]))

cluster_mapping['Id15_v30'] = new_column
cluster_mapping.drop(columns=['id'], inplace=True)
display(cluster_mapping.head())
# Out:
#   cluster  Id15_v30
# 0       1  37240441
# 1       1  37210639
# 2       0  37150512
# 3       1  37230017
# 4       0  37220017

# %%
import numpy as np

# filter out gauged catchments
idxs = all_catchments_gdf['Id15_v30'].isin([np.int64(x) for x in cluster_mapping['Id15_v30'].values])
gauged_catchments_gdf = all_catchments_gdf[idxs]
ungauged_catchments_gdf = all_catchments_gdf[idxs == False]
print(gauged_catchments_gdf.shape)
print(ungauged_catchments_gdf.shape)
# Out:
# (339, 4)
# (3108, 4)

# %%
merged_gdf = gauged_catchments_gdf.merge(cluster_mapping, on='Id15_v30')
merged_gdf['area'] = merged_gdf.geometry.area
print(merged_gdf.shape)
merged_gdf.head()
# Out:
# (339, 5)
#    Id15_v30          area  hypeid  \
# 0  12410010  4.095361e+07      31
# 1  12410023  1.727513e+07      35
# 2  12411515  1.254289e+08      45
# 3  12420023  8.062677e+07      52
# 4  12430399  9.708061e+08      70
#
#                                             geometry cluster
# 0  POLYGON Z ((455692.442 6256547.471 0, 455602.4...       1
# 1  POLYGON Z ((450578.458 6258299.415 0, 450563.4...       1
# 2  POLYGON Z ((461092.449 6250737.547 0, 461057.4...       1
# 3  POLYGON Z ((461359.473 6246241.584 0, 461351.4...       1
# 4  POLYGON Z ((480362.318 6231433.26 0, 480369.39...       1

# %%
cmap = "tab20"
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(8, 5))

# Plot without automatic legend
merged_gdf.sort_values(by="area", ascending=False).plot(
    column="cluster",
    figsize=(25, 15),
    ax=ax,
    legend=False,  # turn off auto legend
    cmap=cmap
)

ax.set_title(f"Fall 2022 Clustering")

# Add Denmark boundary
denmark_boundary = all_catchments_gdf.boundary
denmark_boundary.plot(ax=ax, color='black', linewidth=0.02)

# Axis settings
ax.set_xlim(left=440000, right=730000)
ax.set_ylim(top=6.4e6, bottom=6.05e6)
ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)

# --------------------------------------------------------
#  CUSTOM LEGEND (3 columns, small size, upper-right)
# --------------------------------------------------------
import matplotlib as mpl
import matplotlib.patches as mpatches

# Treat cluster as categorical so we have a stable order
cluster_cat = merged_gdf["cluster"].astype("category")
clusters_ordered = list(cluster_cat.cat.categories)  # ordered categories

# New style colormap access (no deprecation warning)
cmap_obj = mpl.colormaps[cmap]  # or mpl.colormaps.get_cmap(cmap)

n_clusters = len(clusters_ordered)

handles = []
for i, c in enumerate(clusters_ordered):
    # Map category index to [0, 1] range for the colormap
    if n_clusters == 1:
        t = 0.5
    else:
        t = i / (n_clusters - 1)
    color = cmap_obj(t)

    handles.append(
        mpatches.Patch(
            color=color,
            label=str(c)
        )
    )

ax.legend(
    handles=handles,
    title="Clusters",
    loc="upper right",
    bbox_to_anchor=(1, 1),
    ncol=2,  # ⭐ three columns
    fontsize=6,  # small text
    title_fontsize=7,
    frameon=True,
    borderpad=0.3,
    handlelength=1.0
)

plt.tight_layout()
plt.savefig(
    str(Path(cluster_file).parent / Path(cluster_file).stem) + '.png',
    dpi=300, bbox_inches='tight'
)
plt.show()

# %% [markdown]
# # Winter

# %%
cluster_file = r'C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2022.csv'
station_mapping = pd.read_csv(os.getenv('STATION_MAPPING'), dtype=str)
shape_file = Path(os.getenv('SHAPE_FILE'))

# %%
all_catchments_gdf = gpd.read_file(shape_file)
print(all_catchments_gdf.shape)
print(all_catchments_gdf.columns)
all_catchments_gdf.head()
# Out:
# (3447, 4)
# Index(['Id15_v30', 'area', 'hypeid', 'geometry'], dtype='object')
#    Id15_v30          area  hypeid  \
# 0  11100001  3.222040e+07       1
# 1  11100003  3.057747e+07       2
# 2  11100004  1.825017e+07       3
# 3  11100005  1.534746e+07       4
# 4  11100006  1.524262e+07       5
#
#                                             geometry
# 0  POLYGON Z ((477487.121 6325222.212 0, 477543.1...
# 1  POLYGON Z ((474003.147 6316165.657 0, 473870.1...
# 2  MULTIPOLYGON Z (((468046.994 6317094.258 0, 46...
# 3  POLYGON Z ((466052.174 6318307.21 0, 466150.17...
# 4  POLYGON Z ((476077.142 6328208.222 0, 476062.1...

# %%
cluster_mapping = pd.read_csv(cluster_file, dtype=str)
cluster_mapping.columns = ['id', 'cluster']
cluster_mapping.head()
# Out:
#          id cluster
# 0  10000009       1
# 1  10000010       0
# 2  10000011       0
# 3  10000014       1
# 4  10000016       0

# %%
new_column = []
for catchment in cluster_mapping['id'].values:
    new_column.append(np.int64(station_mapping[station_mapping["obsstednr"] == catchment]["Id15_v30"].values[0]))

cluster_mapping['Id15_v30'] = new_column
cluster_mapping.drop(columns=['id'], inplace=True)
display(cluster_mapping.head())
# Out:
#   cluster  Id15_v30
# 0       1  37240441
# 1       0  37210639
# 2       0  37150512
# 3       1  37230017
# 4       0  37220017

# %%
import numpy as np

# filter out gauged catchments
idxs = all_catchments_gdf['Id15_v30'].isin([np.int64(x) for x in cluster_mapping['Id15_v30'].values])
gauged_catchments_gdf = all_catchments_gdf[idxs]
ungauged_catchments_gdf = all_catchments_gdf[idxs == False]
print(gauged_catchments_gdf.shape)
print(ungauged_catchments_gdf.shape)
# Out:
# (345, 4)
# (3102, 4)

# %%
merged_gdf = gauged_catchments_gdf.merge(cluster_mapping, on='Id15_v30')
merged_gdf['area'] = merged_gdf.geometry.area
print(merged_gdf.shape)
merged_gdf.head()
# Out:
# (345, 5)
#    Id15_v30          area  hypeid  \
# 0  12410010  4.095361e+07      31
# 1  12410023  1.727513e+07      35
# 2  12411515  1.254289e+08      45
# 3  12420023  8.062677e+07      52
# 4  12430399  9.708061e+08      70
#
#                                             geometry cluster
# 0  POLYGON Z ((455692.442 6256547.471 0, 455602.4...       1
# 1  POLYGON Z ((450578.458 6258299.415 0, 450563.4...       1
# 2  POLYGON Z ((461092.449 6250737.547 0, 461057.4...       1
# 3  POLYGON Z ((461359.473 6246241.584 0, 461351.4...       1
# 4  POLYGON Z ((480362.318 6231433.26 0, 480369.39...       1

# %%
cmap = "tab20"
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(8, 5))

# Plot without automatic legend
merged_gdf.sort_values(by="area", ascending=False).plot(
    column="cluster",
    figsize=(25, 15),
    ax=ax,
    legend=False,  # turn off auto legend
    cmap=cmap
)

ax.set_title(f"Winter 2022 Clustering")

# Add Denmark boundary
denmark_boundary = all_catchments_gdf.boundary
denmark_boundary.plot(ax=ax, color='black', linewidth=0.02)

# Axis settings
ax.set_xlim(left=440000, right=730000)
ax.set_ylim(top=6.4e6, bottom=6.05e6)
ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)

# --------------------------------------------------------
#  CUSTOM LEGEND (3 columns, small size, upper-right)
# --------------------------------------------------------
import matplotlib as mpl
import matplotlib.patches as mpatches

# Treat cluster as categorical so we have a stable order
cluster_cat = merged_gdf["cluster"].astype("category")
clusters_ordered = list(cluster_cat.cat.categories)  # ordered categories

# New style colormap access (no deprecation warning)
cmap_obj = mpl.colormaps[cmap]  # or mpl.colormaps.get_cmap(cmap)

n_clusters = len(clusters_ordered)

handles = []
for i, c in enumerate(clusters_ordered):
    # Map category index to [0, 1] range for the colormap
    if n_clusters == 1:
        t = 0.5
    else:
        t = i / (n_clusters - 1)
    color = cmap_obj(t)

    handles.append(
        mpatches.Patch(
            color=color,
            label=str(c)
        )
    )

ax.legend(
    handles=handles,
    title="Clusters",
    loc="upper right",
    bbox_to_anchor=(1, 1),
    ncol=2,  # ⭐ three columns
    fontsize=6,  # small text
    title_fontsize=7,
    frameon=True,
    borderpad=0.3,
    handlelength=1.0
)

plt.tight_layout()
plt.savefig(
    str(Path(cluster_file).parent / Path(cluster_file).stem) + '.png',
    dpi=300, bbox_inches='tight'
)
plt.show()

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.cm import get_cmap

# Specify the exact path to the folder containing CSV files
folder_path = Path(r'C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering')

multi_year_plotting = True
if multi_year_plotting:
    print("Starting multi-year plotting...")
    # Create output folder for plots
    output_season_clustering_dir = folder_path  
    output_season_clustering_dir.mkdir(exist_ok=True)
    print(f"Output directory: {output_season_clustering_dir}")

    # Get all CSV files in the folder
    csv_files = sorted(folder_path.glob('*.csv'))
    print(f"Found {len(csv_files)} CSV files to process\n")

    # Pre-compute Denmark boundary once (this can be slow)
    print("Computing Denmark boundary (this may take a moment)...")
    denmark_boundary = all_catchments_gdf.boundary
    print("Denmark boundary computed.\n")

    # FIRST PASS: Collect all unique cluster IDs across all years to ensure consistent color mapping
    print("First pass: Collecting all unique cluster IDs across all years...")
    all_cluster_ids = set()
    for csv_file in csv_files:
        cluster_mapping = pd.read_csv(csv_file, dtype=str)
        cluster_mapping.columns = ['id', 'cluster']
        all_cluster_ids.update(cluster_mapping['cluster'].unique())

    # Sort cluster IDs (as integers) and create consistent color mapping
    # Exclude "other" from the sorted list, we'll add it with a distinct color
    sorted_clusters = sorted([int(c) for c in all_cluster_ids if c != 'other'], reverse=False)
    print(f"Found {len(sorted_clusters)} unique cluster IDs: {sorted_clusters[:10]}...")

    # Create color mapping: use Set1 colormap for regular clusters, distinct gray for "other"
    # Get Set1 colormap colors
    set1_cmap = get_cmap('Set1')
    num_colors = 9  # Set1 has 9 distinct colors
    color_map = {}

    # Assign colors to regular clusters
    for i, cluster_id in enumerate(sorted_clusters):
        color_idx = i % num_colors
        color_map[str(cluster_id)] = set1_cmap(color_idx)

    # Assign distinct color for "other" (gray)
    color_map['other'] = '#808080'  # Gray color

    print(f"Created color mapping for {len(color_map)} categories (including 'other')\n")

    # SECOND PASS: Process each CSV file and plot
    print("Second pass: Processing and plotting files...\n")
    for idx, csv_file in enumerate(csv_files, 1):
        # Get filename without extension for naming
        file_stem = csv_file.stem

        print(f"[{idx}/{len(csv_files)}] Processing: {csv_file.name}...")

        # Load cluster mapping
        cluster_mapping = pd.read_csv(csv_file, dtype=str)
        cluster_mapping.columns = ['id', 'cluster']
        print(f"  Loaded {len(cluster_mapping)} catchments from file")

        # Map to Id15_v30 - FIX: filter out unmapped catchments properly
        valid_rows = []
        new_column = []
        for i, catchment in enumerate(cluster_mapping['id'].values):
            matches = station_mapping[station_mapping["obsstednr"] == catchment]["Id15_v30"].values
            if len(matches) > 0:
                new_column.append(np.int64(matches[0]))
                valid_rows.append(i)
            else:
                print(f"  Warning: No mapping found for catchment {catchment}")

        if len(new_column) == 0:
            print(f"  Skipping {csv_file.name} - no valid mappings found\n")
            continue

        # Only keep rows that have valid mappings
        cluster_mapping = cluster_mapping.iloc[valid_rows].copy()
        cluster_mapping['Id15_v30'] = new_column
        cluster_mapping = cluster_mapping[cluster_mapping['Id15_v30'].notna()]
        cluster_mapping.drop(columns=['id'], inplace=True)
        print(f"  Mapped to {len(cluster_mapping)} valid catchments")

        # Filter to available catchments
        print("  Filtering to available catchments...")
        idxs = all_catchments_gdf['Id15_v30'].isin([np.int64(x) for x in cluster_mapping['Id15_v30'].values])
        gauged_catchments_gdf = all_catchments_gdf[idxs]
        print(f"  Found {len(gauged_catchments_gdf)} catchments in shapefile")

        # Merge shape file and dataframe
        print("  Merging data...")
        merged_gdf = gauged_catchments_gdf.merge(cluster_mapping, on='Id15_v30')
        merged_gdf['area'] = merged_gdf.geometry.area
        print(f"  Merged to {len(merged_gdf)} catchments")

        # Count datapoints per cluster and mark small clusters (<20) as "other"
        print("  Analyzing cluster sizes...")
        cluster_counts = merged_gdf['cluster'].value_counts()
        small_clusters = [str(c) for c in cluster_counts[cluster_counts < 10].index.tolist()]

        if len(small_clusters) > 0:
            print(f"  Found {len(small_clusters)} small clusters with <10 datapoints: {small_clusters}")
            # Mark small clusters as "other"
            merged_gdf['cluster_display'] = merged_gdf['cluster'].astype(str).apply(
                lambda x: 'other' if x in small_clusters else x
            )
        else:
            merged_gdf['cluster_display'] = merged_gdf['cluster'].astype(str)
            print("  No small clusters found (<10 datapoints)")

        # Get unique clusters in the current dataset (after grouping), sorted for consistency
        unique_clusters = sorted([str(c) for c in merged_gdf['cluster_display'].unique()],
                                 key=lambda x: (x == 'other', int(x) if x != 'other' else 0))
        print(f"  Plotting {len(unique_clusters)} cluster categories: {unique_clusters}")

        # Create plot with consistent colors
        print("  Creating plot...")
        fig, ax = plt.subplots(1, 2, figsize=(13, 5))

        # Import Patch for legend
        from matplotlib.patches import Patch

        # For each subplot, plot with consistent colors
        for plot_idx, ascending in enumerate([False, True]):
            sorted_gdf = merged_gdf.sort_values(by="area", ascending=ascending).reset_index(drop=True)

            # Plot individual catchments in sorted order to preserve visual layering
            # This ensures that catchments plotted later appear on top
            for idx, row in sorted_gdf.iterrows():
                cluster_val = str(row['cluster_display'])
                color = color_map[cluster_val]

                # Plot single catchment geometry
                gpd.GeoSeries([row['geometry']]).plot(
                    ax=ax[plot_idx],
                    color=color,
                    edgecolor='none'
                )

            # Add legend with consistent colors
            handles = []
            labels = []
            for cluster_val in unique_clusters:
                color = color_map[cluster_val]
                handles.append(Patch(facecolor=color, edgecolor='none'))
                labels.append(str(cluster_val))

            ax[plot_idx].legend(handles, labels, title='Cluster', bbox_to_anchor=(1.05, 1), loc='upper left')
            ax[plot_idx].set_title("Smallest catchments on top" if plot_idx == 0 else "Largest catchments on top")
            ax[plot_idx].set_aspect('equal')
            ax[plot_idx].axis('off')  # Remove axes for cleaner look

        plt.tight_layout()

        # Add boundary of Denmark using pre-computed boundary
        print("    Adding Denmark boundary...")
        denmark_boundary.plot(ax=ax[0], color='black', linewidth=0.01)
        denmark_boundary.plot(ax=ax[1], color='black', linewidth=0.01)

        # Save plot with filename based on CSV filename
        print("  Saving plot...")
        plot_filename = output_season_clustering_dir / f"{file_stem}.png"
        plt.savefig(plot_filename, dpi=300, bbox_inches='tight')
        plt.close()  # Close to free memory

        print(f"  ✓ Saved: {plot_filename}\n")

    print(f"✓ Plotting complete! All plots saved in: {output_season_clustering_dir}")
    print(f"  Color consistency: Same cluster IDs map to same colors across all years")
    print(f"  Small clusters: Clusters with <20 datapoints are grouped as 'other' (gray)")
# Out:
# Starting multi-year plotting...
# Output directory: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering
# Found 88 CSV files to process
#
# Computing Denmark boundary (this may take a moment)...
# Denmark boundary computed.
#
# First pass: Collecting all unique cluster IDs across all years...
# Found 4 unique cluster IDs: [0, 1, 2, 3]...
# Created color mapping for 5 categories (including 'other')
#
# Second pass: Processing and plotting files...
#
# [1/88] Processing: KMeans_clustering_season_1_seasonYear_2001.csv...
#   Loaded 281 catchments from file
# C:\Users\kscar\AppData\Local\Temp\ipykernel_39120\3769715337.py:41: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   set1_cmap = get_cmap('Set1')
#   Mapped to 281 valid catchments
#   Filtering to available catchments...
#   Found 281 catchments in shapefile
#   Merging data...
#   Merged to 281 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2001.png
#
# [2/88] Processing: KMeans_clustering_season_1_seasonYear_2002.csv...
#   Loaded 281 catchments from file
#   Mapped to 281 valid catchments
#   Filtering to available catchments...
#   Found 281 catchments in shapefile
#   Merging data...
#   Merged to 281 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2002.png
#
# [3/88] Processing: KMeans_clustering_season_1_seasonYear_2003.csv...
#   Loaded 282 catchments from file
#   Mapped to 282 valid catchments
#   Filtering to available catchments...
#   Found 282 catchments in shapefile
#   Merging data...
#   Merged to 282 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2003.png
#
# [4/88] Processing: KMeans_clustering_season_1_seasonYear_2004.csv...
#   Loaded 286 catchments from file
#   Mapped to 286 valid catchments
#   Filtering to available catchments...
#   Found 286 catchments in shapefile
#   Merging data...
#   Merged to 286 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2004.png
#
# [5/88] Processing: KMeans_clustering_season_1_seasonYear_2005.csv...
#   Loaded 300 catchments from file
#   Mapped to 300 valid catchments
#   Filtering to available catchments...
#   Found 300 catchments in shapefile
#   Merging data...
#   Merged to 300 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2005.png
#
# [6/88] Processing: KMeans_clustering_season_1_seasonYear_2006.csv...
#   Loaded 287 catchments from file
#   Mapped to 287 valid catchments
#   Filtering to available catchments...
#   Found 287 catchments in shapefile
#   Merging data...
#   Merged to 287 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2006.png
#
# [7/88] Processing: KMeans_clustering_season_1_seasonYear_2007.csv...
#   Loaded 278 catchments from file
#   Mapped to 278 valid catchments
#   Filtering to available catchments...
#   Found 278 catchments in shapefile
#   Merging data...
#   Merged to 278 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2007.png
#
# [8/88] Processing: KMeans_clustering_season_1_seasonYear_2008.csv...
#   Loaded 268 catchments from file
#   Mapped to 268 valid catchments
#   Filtering to available catchments...
#   Found 268 catchments in shapefile
#   Merging data...
#   Merged to 268 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2008.png
#
# [9/88] Processing: KMeans_clustering_season_1_seasonYear_2010.csv...
#   Loaded 257 catchments from file
#   Mapped to 257 valid catchments
#   Filtering to available catchments...
#   Found 257 catchments in shapefile
#   Merging data...
#   Merged to 257 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2010.png
#
# [10/88] Processing: KMeans_clustering_season_1_seasonYear_2011.csv...
#   Loaded 269 catchments from file
#   Mapped to 269 valid catchments
#   Filtering to available catchments...
#   Found 269 catchments in shapefile
#   Merging data...
#   Merged to 269 catchments
#   Analyzing cluster sizes...
#   No small clusters found (<10 datapoints)
#   Plotting 2 cluster categories: ['0', '1']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2011.png
#
# [11/88] Processing: KMeans_clustering_season_1_seasonYear_2012.csv...
#   Loaded 281 catchments from file
#   Mapped to 281 valid catchments
#   Filtering to available catchments...
#   Found 281 catchments in shapefile
#   Merging data...
#   Merged to 281 catchments
#   Analyzing cluster sizes...
#   No small clusters found (<10 datapoints)
#   Plotting 2 cluster categories: ['0', '1']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2012.png
#
# [12/88] Processing: KMeans_clustering_season_1_seasonYear_2013.csv...
#   Loaded 268 catchments from file
#   Mapped to 268 valid catchments
#   Filtering to available catchments...
#   Found 268 catchments in shapefile
#   Merging data...
#   Merged to 268 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2013.png
#
# [13/88] Processing: KMeans_clustering_season_1_seasonYear_2014.csv...
#   Loaded 266 catchments from file
#   Mapped to 266 valid catchments
#   Filtering to available catchments...
#   Found 266 catchments in shapefile
#   Merging data...
#   Merged to 266 catchments
#   Analyzing cluster sizes...
#   No small clusters found (<10 datapoints)
#   Plotting 3 cluster categories: ['0', '1', '2']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2014.png
#
# [14/88] Processing: KMeans_clustering_season_1_seasonYear_2015.csv...
#   Loaded 267 catchments from file
#   Mapped to 267 valid catchments
#   Filtering to available catchments...
#   Found 267 catchments in shapefile
#   Merging data...
#   Merged to 267 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['3']
#   Plotting 4 cluster categories: ['0', '1', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2015.png
#
# [15/88] Processing: KMeans_clustering_season_1_seasonYear_2016.csv...
#   Loaded 272 catchments from file
#   Mapped to 272 valid catchments
#   Filtering to available catchments...
#   Found 272 catchments in shapefile
#   Merging data...
#   Merged to 272 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2016.png
#
# [16/88] Processing: KMeans_clustering_season_1_seasonYear_2017.csv...
#   Loaded 388 catchments from file
#   Mapped to 388 valid catchments
#   Filtering to available catchments...
#   Found 388 catchments in shapefile
#   Merging data...
#   Merged to 388 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2017.png
#
# [17/88] Processing: KMeans_clustering_season_1_seasonYear_2018.csv...
#   Loaded 400 catchments from file
#   Mapped to 400 valid catchments
#   Filtering to available catchments...
#   Found 400 catchments in shapefile
#   Merging data...
#   Merged to 400 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2018.png
#
# [18/88] Processing: KMeans_clustering_season_1_seasonYear_2019.csv...
#   Loaded 394 catchments from file
#   Mapped to 394 valid catchments
#   Filtering to available catchments...
#   Found 394 catchments in shapefile
#   Merging data...
#   Merged to 394 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2019.png
#
# [19/88] Processing: KMeans_clustering_season_1_seasonYear_2020.csv...
#   Loaded 388 catchments from file
#   Mapped to 388 valid catchments
#   Filtering to available catchments...
#   Found 388 catchments in shapefile
#   Merging data...
#   Merged to 388 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2020.png
#
# [20/88] Processing: KMeans_clustering_season_1_seasonYear_2021.csv...
#   Loaded 384 catchments from file
#   Mapped to 384 valid catchments
#   Filtering to available catchments...
#   Found 384 catchments in shapefile
#   Merging data...
#   Merged to 384 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2021.png
#
# [21/88] Processing: KMeans_clustering_season_1_seasonYear_2022.csv...
#   Loaded 347 catchments from file
#   Mapped to 347 valid catchments
#   Filtering to available catchments...
#   Found 347 catchments in shapefile
#   Merging data...
#   Merged to 347 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_1_seasonYear_2022.png
#
# [22/88] Processing: KMeans_clustering_season_2_seasonYear_2001.csv...
#   Loaded 271 catchments from file
#   Mapped to 271 valid catchments
#   Filtering to available catchments...
#   Found 271 catchments in shapefile
#   Merging data...
#   Merged to 271 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2001.png
#
# [23/88] Processing: KMeans_clustering_season_2_seasonYear_2002.csv...
#   Loaded 276 catchments from file
#   Mapped to 276 valid catchments
#   Filtering to available catchments...
#   Found 276 catchments in shapefile
#   Merging data...
#   Merged to 276 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2002.png
#
# [24/88] Processing: KMeans_clustering_season_2_seasonYear_2003.csv...
#   Loaded 269 catchments from file
#   Mapped to 269 valid catchments
#   Filtering to available catchments...
#   Found 269 catchments in shapefile
#   Merging data...
#   Merged to 269 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2003.png
#
# [25/88] Processing: KMeans_clustering_season_2_seasonYear_2004.csv...
#   Loaded 283 catchments from file
#   Mapped to 283 valid catchments
#   Filtering to available catchments...
#   Found 283 catchments in shapefile
#   Merging data...
#   Merged to 283 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2004.png
#
# [26/88] Processing: KMeans_clustering_season_2_seasonYear_2005.csv...
#   Loaded 294 catchments from file
#   Mapped to 294 valid catchments
#   Filtering to available catchments...
#   Found 294 catchments in shapefile
#   Merging data...
#   Merged to 294 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2005.png
#
# [27/88] Processing: KMeans_clustering_season_2_seasonYear_2006.csv...
#   Loaded 272 catchments from file
#   Mapped to 272 valid catchments
#   Filtering to available catchments...
#   Found 272 catchments in shapefile
#   Merging data...
#   Merged to 272 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2006.png
#
# [28/88] Processing: KMeans_clustering_season_2_seasonYear_2007.csv...
#   Loaded 277 catchments from file
#   Mapped to 277 valid catchments
#   Filtering to available catchments...
#   Found 277 catchments in shapefile
#   Merging data...
#   Merged to 277 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2007.png
#
# [29/88] Processing: KMeans_clustering_season_2_seasonYear_2008.csv...
#   Loaded 263 catchments from file
#   Mapped to 263 valid catchments
#   Filtering to available catchments...
#   Found 263 catchments in shapefile
#   Merging data...
#   Merged to 263 catchments
#   Analyzing cluster sizes...
#   Found 2 small clusters with <10 datapoints: ['2', '1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2008.png
#
# [30/88] Processing: KMeans_clustering_season_2_seasonYear_2009.csv...
#   Loaded 257 catchments from file
#   Mapped to 257 valid catchments
#   Filtering to available catchments...
#   Found 257 catchments in shapefile
#   Merging data...
#   Merged to 257 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2009.png
#
# [31/88] Processing: KMeans_clustering_season_2_seasonYear_2010.csv...
#   Loaded 250 catchments from file
#   Mapped to 250 valid catchments
#   Filtering to available catchments...
#   Found 250 catchments in shapefile
#   Merging data...
#   Merged to 250 catchments
#   Analyzing cluster sizes...
#   Found 2 small clusters with <10 datapoints: ['1', '2']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2010.png
#
# [32/88] Processing: KMeans_clustering_season_2_seasonYear_2011.csv...
#   Loaded 269 catchments from file
#   Mapped to 269 valid catchments
#   Filtering to available catchments...
#   Found 269 catchments in shapefile
#   Merging data...
#   Merged to 269 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2011.png
#
# [33/88] Processing: KMeans_clustering_season_2_seasonYear_2012.csv...
#   Loaded 276 catchments from file
#   Mapped to 276 valid catchments
#   Filtering to available catchments...
#   Found 276 catchments in shapefile
#   Merging data...
#   Merged to 276 catchments
#   Analyzing cluster sizes...
#   No small clusters found (<10 datapoints)
#   Plotting 3 cluster categories: ['0', '1', '2']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2012.png
#
# [34/88] Processing: KMeans_clustering_season_2_seasonYear_2013.csv...
#   Loaded 262 catchments from file
#   Mapped to 262 valid catchments
#   Filtering to available catchments...
#   Found 262 catchments in shapefile
#   Merging data...
#   Merged to 262 catchments
#   Analyzing cluster sizes...
#   No small clusters found (<10 datapoints)
#   Plotting 3 cluster categories: ['0', '1', '2']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2013.png
#
# [35/88] Processing: KMeans_clustering_season_2_seasonYear_2014.csv...
#   Loaded 260 catchments from file
#   Mapped to 260 valid catchments
#   Filtering to available catchments...
#   Found 260 catchments in shapefile
#   Merging data...
#   Merged to 260 catchments
#   Analyzing cluster sizes...
#   No small clusters found (<10 datapoints)
#   Plotting 3 cluster categories: ['0', '1', '2']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2014.png
#
# [36/88] Processing: KMeans_clustering_season_2_seasonYear_2015.csv...
#   Loaded 265 catchments from file
#   Mapped to 265 valid catchments
#   Filtering to available catchments...
#   Found 265 catchments in shapefile
#   Merging data...
#   Merged to 265 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2015.png
#
# [37/88] Processing: KMeans_clustering_season_2_seasonYear_2016.csv...
#   Loaded 268 catchments from file
#   Mapped to 268 valid catchments
#   Filtering to available catchments...
#   Found 268 catchments in shapefile
#   Merging data...
#   Merged to 268 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2016.png
#
# [38/88] Processing: KMeans_clustering_season_2_seasonYear_2017.csv...
#   Loaded 382 catchments from file
#   Mapped to 382 valid catchments
#   Filtering to available catchments...
#   Found 382 catchments in shapefile
#   Merging data...
#   Merged to 382 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2017.png
#
# [39/88] Processing: KMeans_clustering_season_2_seasonYear_2018.csv...
#   Loaded 390 catchments from file
#   Mapped to 390 valid catchments
#   Filtering to available catchments...
#   Found 390 catchments in shapefile
#   Merging data...
#   Merged to 390 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2018.png
#
# [40/88] Processing: KMeans_clustering_season_2_seasonYear_2019.csv...
#   Loaded 382 catchments from file
#   Mapped to 382 valid catchments
#   Filtering to available catchments...
#   Found 382 catchments in shapefile
#   Merging data...
#   Merged to 382 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2019.png
#
# [41/88] Processing: KMeans_clustering_season_2_seasonYear_2020.csv...
#   Loaded 374 catchments from file
#   Mapped to 374 valid catchments
#   Filtering to available catchments...
#   Found 374 catchments in shapefile
#   Merging data...
#   Merged to 374 catchments
#   Analyzing cluster sizes...
#   Found 2 small clusters with <10 datapoints: ['2', '1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2020.png
#
# [42/88] Processing: KMeans_clustering_season_2_seasonYear_2021.csv...
#   Loaded 374 catchments from file
#   Mapped to 374 valid catchments
#   Filtering to available catchments...
#   Found 374 catchments in shapefile
#   Merging data...
#   Merged to 374 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2021.png
#
# [43/88] Processing: KMeans_clustering_season_2_seasonYear_2022.csv...
#   Loaded 335 catchments from file
#   Mapped to 335 valid catchments
#   Filtering to available catchments...
#   Found 335 catchments in shapefile
#   Merging data...
#   Merged to 335 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_2_seasonYear_2022.png
#
# [44/88] Processing: KMeans_clustering_season_3_seasonYear_2001.csv...
#   Loaded 276 catchments from file
#   Mapped to 276 valid catchments
#   Filtering to available catchments...
#   Found 276 catchments in shapefile
#   Merging data...
#   Merged to 276 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2001.png
#
# [45/88] Processing: KMeans_clustering_season_3_seasonYear_2002.csv...
#   Loaded 273 catchments from file
#   Mapped to 273 valid catchments
#   Filtering to available catchments...
#   Found 273 catchments in shapefile
#   Merging data...
#   Merged to 273 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2002.png
#
# [46/88] Processing: KMeans_clustering_season_3_seasonYear_2003.csv...
#   Loaded 272 catchments from file
#   Mapped to 272 valid catchments
#   Filtering to available catchments...
#   Found 272 catchments in shapefile
#   Merging data...
#   Merged to 272 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2003.png
#
# [47/88] Processing: KMeans_clustering_season_3_seasonYear_2004.csv...
#   Loaded 291 catchments from file
#   Mapped to 291 valid catchments
#   Filtering to available catchments...
#   Found 291 catchments in shapefile
#   Merging data...
#   Merged to 291 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2004.png
#
# [48/88] Processing: KMeans_clustering_season_3_seasonYear_2005.csv...
#   Loaded 292 catchments from file
#   Mapped to 292 valid catchments
#   Filtering to available catchments...
#   Found 292 catchments in shapefile
#   Merging data...
#   Merged to 292 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2005.png
#
# [49/88] Processing: KMeans_clustering_season_3_seasonYear_2006.csv...
#   Loaded 274 catchments from file
#   Mapped to 274 valid catchments
#   Filtering to available catchments...
#   Found 274 catchments in shapefile
#   Merging data...
#   Merged to 274 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2006.png
#
# [50/88] Processing: KMeans_clustering_season_3_seasonYear_2007.csv...
#   Loaded 279 catchments from file
#   Mapped to 279 valid catchments
#   Filtering to available catchments...
#   Found 279 catchments in shapefile
#   Merging data...
#   Merged to 279 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2007.png
#
# [51/88] Processing: KMeans_clustering_season_3_seasonYear_2008.csv...
#   Loaded 263 catchments from file
#   Mapped to 263 valid catchments
#   Filtering to available catchments...
#   Found 263 catchments in shapefile
#   Merging data...
#   Merged to 263 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2008.png
#
# [52/88] Processing: KMeans_clustering_season_3_seasonYear_2009.csv...
#   Loaded 259 catchments from file
#   Mapped to 259 valid catchments
#   Filtering to available catchments...
#   Found 259 catchments in shapefile
#   Merging data...
#   Merged to 259 catchments
#   Analyzing cluster sizes...
#   Found 2 small clusters with <10 datapoints: ['2', '1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2009.png
#
# [53/88] Processing: KMeans_clustering_season_3_seasonYear_2010.csv...
#   Loaded 254 catchments from file
#   Mapped to 254 valid catchments
#   Filtering to available catchments...
#   Found 254 catchments in shapefile
#   Merging data...
#   Merged to 254 catchments
#   Analyzing cluster sizes...
#   Found 2 small clusters with <10 datapoints: ['2', '1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2010.png
#
# [54/88] Processing: KMeans_clustering_season_3_seasonYear_2011.csv...
#   Loaded 275 catchments from file
#   Mapped to 275 valid catchments
#   Filtering to available catchments...
#   Found 275 catchments in shapefile
#   Merging data...
#   Merged to 275 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2011.png
#
# [55/88] Processing: KMeans_clustering_season_3_seasonYear_2012.csv...
#   Loaded 277 catchments from file
#   Mapped to 277 valid catchments
#   Filtering to available catchments...
#   Found 277 catchments in shapefile
#   Merging data...
#   Merged to 277 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2012.png
#
# [56/88] Processing: KMeans_clustering_season_3_seasonYear_2013.csv...
#   Loaded 267 catchments from file
#   Mapped to 267 valid catchments
#   Filtering to available catchments...
#   Found 267 catchments in shapefile
#   Merging data...
#   Merged to 267 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2013.png
#
# [57/88] Processing: KMeans_clustering_season_3_seasonYear_2014.csv...
#   Loaded 263 catchments from file
#   Mapped to 263 valid catchments
#   Filtering to available catchments...
#   Found 263 catchments in shapefile
#   Merging data...
#   Merged to 263 catchments
#   Analyzing cluster sizes...
#   No small clusters found (<10 datapoints)
#   Plotting 3 cluster categories: ['0', '1', '2']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2014.png
#
# [58/88] Processing: KMeans_clustering_season_3_seasonYear_2015.csv...
#   Loaded 265 catchments from file
#   Mapped to 265 valid catchments
#   Filtering to available catchments...
#   Found 265 catchments in shapefile
#   Merging data...
#   Merged to 265 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2015.png
#
# [59/88] Processing: KMeans_clustering_season_3_seasonYear_2016.csv...
#   Loaded 267 catchments from file
#   Mapped to 267 valid catchments
#   Filtering to available catchments...
#   Found 267 catchments in shapefile
#   Merging data...
#   Merged to 267 catchments
#   Analyzing cluster sizes...
#   Found 2 small clusters with <10 datapoints: ['0', '1']
#   Plotting 2 cluster categories: ['2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2016.png
#
# [60/88] Processing: KMeans_clustering_season_3_seasonYear_2017.csv...
#   Loaded 388 catchments from file
#   Mapped to 388 valid catchments
#   Filtering to available catchments...
#   Found 388 catchments in shapefile
#   Merging data...
#   Merged to 388 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2017.png
#
# [61/88] Processing: KMeans_clustering_season_3_seasonYear_2018.csv...
#   Loaded 392 catchments from file
#   Mapped to 392 valid catchments
#   Filtering to available catchments...
#   Found 392 catchments in shapefile
#   Merging data...
#   Merged to 392 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2018.png
#
# [62/88] Processing: KMeans_clustering_season_3_seasonYear_2019.csv...
#   Loaded 389 catchments from file
#   Mapped to 389 valid catchments
#   Filtering to available catchments...
#   Found 389 catchments in shapefile
#   Merging data...
#   Merged to 389 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2019.png
#
# [63/88] Processing: KMeans_clustering_season_3_seasonYear_2020.csv...
#   Loaded 381 catchments from file
#   Mapped to 381 valid catchments
#   Filtering to available catchments...
#   Found 381 catchments in shapefile
#   Merging data...
#   Merged to 381 catchments
#   Analyzing cluster sizes...
#   Found 2 small clusters with <10 datapoints: ['1', '2']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2020.png
#
# [64/88] Processing: KMeans_clustering_season_3_seasonYear_2021.csv...
#   Loaded 374 catchments from file
#   Mapped to 374 valid catchments
#   Filtering to available catchments...
#   Found 374 catchments in shapefile
#   Merging data...
#   Merged to 374 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2021.png
#
# [65/88] Processing: KMeans_clustering_season_3_seasonYear_2022.csv...
#   Loaded 339 catchments from file
#   Mapped to 339 valid catchments
#   Filtering to available catchments...
#   Found 339 catchments in shapefile
#   Merging data...
#   Merged to 339 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_3_seasonYear_2022.png
#
# [66/88] Processing: KMeans_clustering_season_4_seasonYear_2000.csv...
#   Loaded 280 catchments from file
#   Mapped to 280 valid catchments
#   Filtering to available catchments...
#   Found 280 catchments in shapefile
#   Merging data...
#   Merged to 280 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2000.png
#
# [67/88] Processing: KMeans_clustering_season_4_seasonYear_2001.csv...
#   Loaded 282 catchments from file
#   Mapped to 282 valid catchments
#   Filtering to available catchments...
#   Found 282 catchments in shapefile
#   Merging data...
#   Merged to 282 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2001.png
#
# [68/88] Processing: KMeans_clustering_season_4_seasonYear_2002.csv...
#   Loaded 281 catchments from file
#   Mapped to 281 valid catchments
#   Filtering to available catchments...
#   Found 281 catchments in shapefile
#   Merging data...
#   Merged to 281 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2002.png
#
# [69/88] Processing: KMeans_clustering_season_4_seasonYear_2003.csv...
#   Loaded 280 catchments from file
#   Mapped to 280 valid catchments
#   Filtering to available catchments...
#   Found 280 catchments in shapefile
#   Merging data...
#   Merged to 280 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2003.png
#
# [70/88] Processing: KMeans_clustering_season_4_seasonYear_2004.csv...
#   Loaded 292 catchments from file
#   Mapped to 292 valid catchments
#   Filtering to available catchments...
#   Found 292 catchments in shapefile
#   Merging data...
#   Merged to 292 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2004.png
#
# [71/88] Processing: KMeans_clustering_season_4_seasonYear_2005.csv...
#   Loaded 284 catchments from file
#   Mapped to 284 valid catchments
#   Filtering to available catchments...
#   Found 284 catchments in shapefile
#   Merging data...
#   Merged to 284 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2005.png
#
# [72/88] Processing: KMeans_clustering_season_4_seasonYear_2006.csv...
#   Loaded 265 catchments from file
#   Mapped to 265 valid catchments
#   Filtering to available catchments...
#   Found 265 catchments in shapefile
#   Merging data...
#   Merged to 265 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2006.png
#
# [73/88] Processing: KMeans_clustering_season_4_seasonYear_2007.csv...
#   Loaded 264 catchments from file
#   Mapped to 264 valid catchments
#   Filtering to available catchments...
#   Found 264 catchments in shapefile
#   Merging data...
#   Merged to 264 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2007.png
#
# [74/88] Processing: KMeans_clustering_season_4_seasonYear_2008.csv...
#   Loaded 266 catchments from file
#   Mapped to 266 valid catchments
#   Filtering to available catchments...
#   Found 266 catchments in shapefile
#   Merging data...
#   Merged to 266 catchments
#   Analyzing cluster sizes...
#   Found 2 small clusters with <10 datapoints: ['2', '1']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2008.png
#
# [75/88] Processing: KMeans_clustering_season_4_seasonYear_2009.csv...
#   Loaded 255 catchments from file
#   Mapped to 255 valid catchments
#   Filtering to available catchments...
#   Found 255 catchments in shapefile
#   Merging data...
#   Merged to 255 catchments
#   Analyzing cluster sizes...
#   Found 2 small clusters with <10 datapoints: ['1', '2']
#   Plotting 2 cluster categories: ['0', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2009.png
#
# [76/88] Processing: KMeans_clustering_season_4_seasonYear_2010.csv...
#   Loaded 252 catchments from file
#   Mapped to 252 valid catchments
#   Filtering to available catchments...
#   Found 252 catchments in shapefile
#   Merging data...
#   Merged to 252 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2010.png
#
# [77/88] Processing: KMeans_clustering_season_4_seasonYear_2011.csv...
#   Loaded 262 catchments from file
#   Mapped to 262 valid catchments
#   Filtering to available catchments...
#   Found 262 catchments in shapefile
#   Merging data...
#   Merged to 262 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2011.png
#
# [78/88] Processing: KMeans_clustering_season_4_seasonYear_2012.csv...
#   Loaded 249 catchments from file
#   Mapped to 249 valid catchments
#   Filtering to available catchments...
#   Found 249 catchments in shapefile
#   Merging data...
#   Merged to 249 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2012.png
#
# [79/88] Processing: KMeans_clustering_season_4_seasonYear_2013.csv...
#   Loaded 242 catchments from file
#   Mapped to 242 valid catchments
#   Filtering to available catchments...
#   Found 242 catchments in shapefile
#   Merging data...
#   Merged to 242 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2013.png
#
# [80/88] Processing: KMeans_clustering_season_4_seasonYear_2014.csv...
#   Loaded 245 catchments from file
#   Mapped to 245 valid catchments
#   Filtering to available catchments...
#   Found 245 catchments in shapefile
#   Merging data...
#   Merged to 245 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2014.png
#
# [81/88] Processing: KMeans_clustering_season_4_seasonYear_2015.csv...
#   Loaded 239 catchments from file
#   Mapped to 239 valid catchments
#   Filtering to available catchments...
#   Found 239 catchments in shapefile
#   Merging data...
#   Merged to 239 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2015.png
#
# [82/88] Processing: KMeans_clustering_season_4_seasonYear_2016.csv...
#   Loaded 248 catchments from file
#   Mapped to 248 valid catchments
#   Filtering to available catchments...
#   Found 248 catchments in shapefile
#   Merging data...
#   Merged to 248 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['0']
#   Plotting 3 cluster categories: ['1', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2016.png
#
# [83/88] Processing: KMeans_clustering_season_4_seasonYear_2017.csv...
#   Loaded 369 catchments from file
#   Mapped to 369 valid catchments
#   Filtering to available catchments...
#   Found 369 catchments in shapefile
#   Merging data...
#   Merged to 369 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2017.png
#
# [84/88] Processing: KMeans_clustering_season_4_seasonYear_2018.csv...
#   Loaded 383 catchments from file
#   Mapped to 383 valid catchments
#   Filtering to available catchments...
#   Found 383 catchments in shapefile
#   Merging data...
#   Merged to 383 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2018.png
#
# [85/88] Processing: KMeans_clustering_season_4_seasonYear_2019.csv...
#   Loaded 379 catchments from file
#   Mapped to 379 valid catchments
#   Filtering to available catchments...
#   Found 379 catchments in shapefile
#   Merging data...
#   Merged to 379 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2019.png
#
# [86/88] Processing: KMeans_clustering_season_4_seasonYear_2020.csv...
#   Loaded 378 catchments from file
#   Mapped to 378 valid catchments
#   Filtering to available catchments...
#   Found 378 catchments in shapefile
#   Merging data...
#   Merged to 378 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['1']
#   Plotting 3 cluster categories: ['0', '2', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2020.png
#
# [87/88] Processing: KMeans_clustering_season_4_seasonYear_2021.csv...
#   Loaded 348 catchments from file
#   Mapped to 348 valid catchments
#   Filtering to available catchments...
#   Found 348 catchments in shapefile
#   Merging data...
#   Merged to 348 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2021.png
#
# [88/88] Processing: KMeans_clustering_season_4_seasonYear_2022.csv...
#   Loaded 345 catchments from file
#   Mapped to 345 valid catchments
#   Filtering to available catchments...
#   Found 345 catchments in shapefile
#   Merging data...
#   Merged to 345 catchments
#   Analyzing cluster sizes...
#   Found 1 small clusters with <10 datapoints: ['2']
#   Plotting 3 cluster categories: ['0', '1', 'other']
#   Creating plot...
#     Adding Denmark boundary...
#   Saving plot...
#   ✓ Saved: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering\KMeans_clustering_season_4_seasonYear_2022.png
#
# ✓ Plotting complete! All plots saved in: C:\Users\kscar\Documents\GitHub\02807_Project\output\season_clustering
#   Color consistency: Same cluster IDs map to same colors across all years
#   Small clusters: Clusters with <20 datapoints are grouped as 'other' (gray)
